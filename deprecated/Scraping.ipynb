# %% [markdown]
# ## Scraping to create feature variables

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import chromedriver_binary 
import os
import re
import requests
import json
import csv 
import nltk
import xml.etree.ElementTree as ET


# Features - Number of Words, Num of Unique Words, etc. 
#

# %% [markdown]
# ## Function to extract the XML files from the SiteMap
#
# The extract_xml_files_from_sitemap function takes a sitemap_url parameter, downloads the sitemap file using requests.get, and parses the XML content using xml.etree.ElementTree. It then finds all the <loc> elements in the sitemap using the appropriate namespace, filters the URLs to only include those ending with .xml, and returns a list of the XML file URLs.

# %%
def extract_xml_files_from_sitemap(sitemap_url):
    # Download the sitemap file
    response = requests.get(sitemap_url)
    sitemap_content = response.content

    # Parse the XML content
    root = ET.fromstring(sitemap_content)

    # Find all the URLs in the sitemap
    urls = root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")

    # Extract the XML file URLs
    xml_files = [url.text for url in urls if url.text.endswith(".xml")]

    return xml_files

sitemap_url = "https://docs.netapp.com/cloud/sitemap.xml"
xml_files = extract_xml_files_from_sitemap(sitemap_url)

for file in xml_files: 
    print(file)
# Out:
# https://docs.netapp.com/cloud/sitemap-us-en.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager/sitemap.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager-97/sitemap.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager-98/sitemap.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager-99/sitemap.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager-910/sitemap.xml
# https://docs.netapp.com/us-en/active-iq-unified-manager-912/sitemap.xml
# https://docs.netapp.com/us-en/active-iq/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation-2211/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation-2208/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation-2204/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation-2112/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation-2108/sitemap.xml
# https://docs.netapp.com/us-en/astra-automation/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-center-2211/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-center-2204/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-center-2112/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-center-2108/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-center/sitemap.xml
# https://docs.netapp.com/us-en/astra-control-service/sitemap.xml
# https://docs.netapp.com/us-en/astra-family/sitemap.xml
# https://docs.netapp.com/us-en/beegfs/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-automation/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-azure-netapp-files/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-backup-recovery/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-backup-recovery-vm/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-blob-storage/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-cloud-volumes-ontap/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-classification/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-cloud-volumes-service-gcp/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-cloud-ops/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-copy-sync/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-digital-wallet/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-economic-efficiency/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-edge-caching/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-e-series/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-family/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-fsx-ontap/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-google-cloud-storage/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-kubernetes/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-ontap-onprem/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-operational-resiliency/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-ransomware-protection/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-remediation/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-replication/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-reports/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-s3-storage/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-setup-admin/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-storagegrid/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-tiering/sitemap.xml
# https://docs.netapp.com/us-en/bluexp-volume-caching/sitemap.xml
# https://docs.netapp.com/us-en/cloud-manager-cloud-volumes-service-aws/sitemap.xml
# https://docs.netapp.com/us-en/cloud-manager-snapcenter/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9100-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9101-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9110-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9111-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9120-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9121-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-9130-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-93-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-94-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-95-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-96-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-97-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-98-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-990-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-991-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloud-volumes-ontap-relnotes/sitemap.xml
# https://docs.netapp.com/us-en/cloudinsights/sitemap.xml
# https://docs.netapp.com/us-en/cloud_volumes/sitemap.xml
# https://docs.netapp.com/us-en/converged-systems-advisor/sitemap.xml
# https://docs.netapp.com/us-en/e-series/sitemap.xml
# https://docs.netapp.com/us-en/e-series-cli/sitemap.xml
# https://docs.netapp.com/us-en/e-series-family/sitemap.xml
# https://docs.netapp.com/us-en/e-series-santricity/sitemap.xml
# https://docs.netapp.com/us-en/e-series-santricity-115/sitemap.xml
# https://docs.netapp.com/us-en/e-series-santricity-116/sitemap.xml
# https://docs.netapp.com/us-en/element-software/sitemap.xml
# https://docs.netapp.com/us-en/element-software-123/sitemap.xml
# https://docs.netapp.com/us-en/flexpod/sitemap.xml
# https://docs.netapp.com/us-en/hci-solutions/sitemap.xml
# https://docs.netapp.com/us-en/hci/sitemap.xml
# https://docs.netapp.com/us-en/hci18/sitemap.xml
# https://docs.netapp.com/us-en/hci19/sitemap.xml
# https://docs.netapp.com/us-en/hybridcloudsolutions/sitemap.xml
# https://docs.netapp.com/us-en/interoperability-matrix-tool/sitemap.xml
# https://docs.netapp.com/us-en/keystone/sitemap.xml
# https://docs.netapp.com/us-en/keystone-staas/sitemap.xml
# https://docs.netapp.com/us-en/netapp-automation/sitemap.xml
# https://docs.netapp.com/us-en/netapp-solutions-sap/sitemap.xml
# https://docs.netapp.com/us-en/netapp-solutions/sitemap.xml
# https://docs.netapp.com/us-en/nfs-plugin-vmware-vaai/sitemap.xml
# https://docs.netapp.com/us-en/oncommand-insight/sitemap.xml
# https://docs.netapp.com/us-en/oncommand-unified-manager-95/sitemap.xml
# https://docs.netapp.com/us-en/ontap/sitemap.xml
# https://docs.netapp.com/us-en/ontap-7mode-transition/sitemap.xml
# https://docs.netapp.com/us-en/ontap-automation/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-93/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-95/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-96/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-97/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-98/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-991/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-9101/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-9111/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-9121/sitemap.xml
# https://docs.netapp.com/us-en/ontap-cli-9131/sitemap.xml
# https://docs.netapp.com/us-en/ontap-ems-9101/sitemap.xml
# https://docs.netapp.com/us-en/ontap-ems-9111/sitemap.xml
# https://docs.netapp.com/us-en/ontap-ems-9121/sitemap.xml
# https://docs.netapp.com/us-en/ontap-ems-9131/sitemap.xml
# https://docs.netapp.com/us-en/ontap-family/sitemap.xml
# https://docs.netapp.com/us-en/ontap-flexarray/sitemap.xml
# https://docs.netapp.com/us-en/ontap-fli/sitemap.xml
# https://docs.netapp.com/us-en/ontap-metrocluster/sitemap.xml
# https://docs.netapp.com/us-en/ontap-pcmap-9111/sitemap.xml
# https://docs.netapp.com/us-en/ontap-pcmap-9121/sitemap.xml
# https://docs.netapp.com/us-en/ontap-pcmap-9131/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-98/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-991/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-9101/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-9111/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-9121/sitemap.xml
# https://docs.netapp.com/us-en/ontap-restmap-9131/sitemap.xml
# https://docs.netapp.com/us-en/ontap-sanhost/sitemap.xml
# https://docs.netapp.com/us-en/ontap-select/sitemap.xml
# https://docs.netapp.com/us-en/ontap-sm-classic/sitemap.xml
# https://docs.netapp.com/us-en/ontap-systems/sitemap.xml
# https://docs.netapp.com/us-en/ontap-systems-family/sitemap.xml
# https://docs.netapp.com/us-en/ontap-systems-switches/sitemap.xml
# https://docs.netapp.com/us-en/ontap-systems-upgrade/sitemap.xml
# https://docs.netapp.com/us-en/ontap-technical-reports/sitemap.xml
# https://docs.netapp.com/us-en/ontap-tools-vmware-vsphere/sitemap.xml
# https://docs.netapp.com/us-en/ontap-tools-vmware-vsphere-911/sitemap.xml
# https://docs.netapp.com/us-en/ontap-tools-vmware-vsphere-910/sitemap.xml
# https://docs.netapp.com/us-en/ontap-tools-vmware-vsphere-98/sitemap.xml
# https://docs.netapp.com/us-en/ontap-whatsnew/sitemap.xml
# https://docs.netapp.com/us-en/saasbackup-partnercentral/sitemap.xml
# https://docs.netapp.com/us-en/saasbackupO365/sitemap.xml
# https://docs.netapp.com/us-en/salesforce/sitemap.xml
# https://docs.netapp.com/us-en/sc-plugin-vmware-vsphere/sitemap.xml
# https://docs.netapp.com/us-en/sc-plugin-vmware-vsphere-45/sitemap.xml
# https://docs.netapp.com/us-en/sc-plugin-vmware-vsphere-46/sitemap.xml
# https://docs.netapp.com/us-en/sc-plugin-vmware-vsphere-47/sitemap.xml
# https://docs.netapp.com/us-en/sc-plugin-vmware-vsphere-48/sitemap.xml
# https://docs.netapp.com/us-en/smis-provider/sitemap.xml
# https://docs.netapp.com/us-en/snap-creator-framework/sitemap.xml
# https://docs.netapp.com/us-en/snapcenter/sitemap.xml
# https://docs.netapp.com/us-en/snapcenter-45/sitemap.xml
# https://docs.netapp.com/us-en/snapcenter-46/sitemap.xml
# https://docs.netapp.com/us-en/snapcenter-47/sitemap.xml
# https://docs.netapp.com/us-en/snapcenter-48/sitemap.xml
# https://docs.netapp.com/us-en/snapdrive-unix/sitemap.xml
# https://docs.netapp.com/us-en/snapmanager-hyper-v/sitemap.xml
# https://docs.netapp.com/us-en/snapmanager-oracle/sitemap.xml
# https://docs.netapp.com/us-en/snapmanager-sap/sitemap.xml
# https://docs.netapp.com/us-en/solidfire-active-iq/sitemap.xml
# https://docs.netapp.com/us-en/storagegrid-115/sitemap.xml
# https://docs.netapp.com/us-en/storagegrid-116/sitemap.xml
# https://docs.netapp.com/us-en/storagegrid-117/sitemap.xml
# https://docs.netapp.com/us-en/storagegrid-enable/sitemap.xml
# https://docs.netapp.com/us-en/trident/sitemap.xml
# https://docs.netapp.com/us-en/trident-2107/sitemap.xml
# https://docs.netapp.com/us-en/trident-2110/sitemap.xml
# https://docs.netapp.com/us-en/trident-2201/sitemap.xml
# https://docs.netapp.com/us-en/trident-2204/sitemap.xml
# https://docs.netapp.com/us-en/trident-2207/sitemap.xml
# https://docs.netapp.com/us-en/trident-2210/sitemap.xml
# https://docs.netapp.com/us-en/trident-2301/sitemap.xml
# https://docs.netapp.com/us-en/vcp/sitemap.xml
# https://docs.netapp.com/us-en/virtual-desktop-managed-service/sitemap.xml
# https://docs.netapp.com/us-en/virtual-desktop-service/sitemap.xml
# https://docs.netapp.com/us-en/vsc-vasa-provider-sra-97/sitemap.xml
# https://docs.netapp.com/us-en/workflow-automation/sitemap.xml
# https://docs.netapp.com/us-en/workflow-automation-50/sitemap.xml
# https://docs.netapp.com/us-en/xcp/sitemap.xml

# %% [markdown]
# ## Extract the html files from a given xml file on the sitemap
#
# This code downloads the XML sitemap using requests.get, parses it using xml.etree.ElementTree, and then finds all the <loc> elements using the appropriate namespace. It filters the URLs to include only those ending with .html and returns a list of HTML file URLs.

# %%
def extract_html_files_from_sitemap(xml_url):
    # Download the sitemap file
    response = requests.get(xml_url)
    sitemap_content = response.content

    # Parse the XML content
    root = ET.fromstring(sitemap_content)

    # Find all the URLs in the sitemap
    urls = root.findall(".//{http://www.sitemaps.org/schemas/sitemap/0.9}loc")

    # Extract the HTML file URLs
    html_files = [url.text for url in urls if url.text.endswith(".html")]

    return html_files

# %% [markdown]
# ## Creating a List of all HTML Files

# %%
all_html_files =[]
final_html_files =[]
for file in range(10,20):
    html_files = extract_html_files_from_sitemap(xml_files[file])
    all_html_files.append(html_files)
for l in all_html_files:
    final_html_files += l
    

print(len(all_html_files))
# Out:
# 10

# %% [markdown]
# ## Creating CSV of HTML Files and Their Features

# %%
import csv
from itertools import zip_longest
d = [final_html_files]
export_data = zip_longest(*d, fillvalue = '')
with open('new_output.csv', 'w', encoding="ISO-8859-1", newline='') as myfile:
    wr = csv.writer(myfile)
    wr.writerows(export_data)
myfile.close()
df = pd.read_csv('new_output.csv')
df.to_csv('new_output.csv')

df = pd.read_csv('new_output.csv')
first_column = df.columns[0]
df = df.drop([first_column], axis=1)
df.to_csv('new_output.csv', index=False)

# %% [markdown]
# ## Converting documents into text files

# %%
import re
def convert_html_to_text(url, output_file):
    # Fetch the HTML content from the URL
    response = requests.get(url)
    html_page = response.content
    soup = BeautifulSoup(html_page, 'html.parser')
    res = soup.find("article", id="main")
    text = res.get_text()
    text = text.strip()
    text = re.sub(r'\r\n|\r', ' ', text)
    # Write the text to a text file
    with open(output_file, "w") as file:
        file.write(text)

df = pd.read_csv('new_output.csv', header = None)
matrix1 = df[df.columns[0]].to_numpy()
urls = matrix1.tolist()

file_l = []
for i, url in enumerate(urls):
    output_file = f"files/output{i+1}.txt"  # Generate output file name
    file_l.append(output_file)
    convert_html_to_text(url, output_file)
df.insert(1,"File Name", file_l)
df.to_csv("new_output.csv")

# %% [markdown]
# Scraping URLs to find the total number of words and total number of unique words in each document.
# extract_words is a function that reads all the words in a file and stores them in a list.

# %%
# Extracts a list of all the words in the html document
def extract_words(text):
    words = []
    text_nodes  = text.split()
    for text in text_nodes:
        words.append(text)
    return words

# Function to find the number of words in the document
def calc_total_words_in_doc(word_list):
    total_words = []
    total_words.append(len(word_list))
    return total_words

def calc_unique_words_in_doc(word_list):
    total_words = []
    unique_words = []
    total_words.append(len(word_list))
    wordset = set(word_list)
    unique_words.append(len(wordset))
    return unique_words

final_total_words =[]
final_unique_words = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    word_list = extract_words(text)
    total_words = calc_total_words_in_doc(word_list)
    final_total_words.append(total_words[0])
    unique_words = calc_unique_words_in_doc(word_list)
    final_unique_words.append(unique_words[0])

df.insert(2,"Total Words", final_total_words)
df.insert(3,"Unique Words", final_unique_words)
df.to_csv("new_output.csv")

# %% [markdown]
# ## Total Number of Sentences in the Document

# %%
from nltk.tokenize import sent_tokenize
nltk.download('punkt')

def count_sentences(content):
    sentences = sent_tokenize(content)
    return len(sentences)


file_list = os.listdir("./files/")
sentence_counts = []
for file in file_list:
    text = open(f"./files/{file}").read()
    sentence_count = count_sentences(text)
    sentence_counts.append(sentence_count)
df.insert(4,"Total Sentence", sentence_counts)
df.to_csv("new_output.csv")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikki\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Syllables in Each Document
#
# The count_syllables() function takes a word as input and uses the CMU Pronouncing Dictionary from NLTK (cmudict) to find the number of syllables in that word. The count_syllables_in_document() function takes a URL as input, retrieves the content using requests.get(), splits the content into words, and counts the total number of syllables by summing the syllable count for each word.

# %%
from nltk.corpus import cmudict
nltk.download('cmudict')
import syllables


# Function to count syllables in a word
def count_syllables(word):
    syllable_count = syllables.estimate(word.strip())
    return syllable_count

# Function to count syllables in a document
def count_syllables_in_document(content):
    words = content.split()
    ctr = 0
    for word in words:
        ctr += count_syllables(word)
    return ctr

syllable_counts = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    syllable_count = count_syllables_in_document(text)
    syllable_counts.append(syllable_count)
df.insert(5,"Total Syllables", syllable_counts)
df.to_csv("new_output.csv")
# Out:
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\nikki\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %% [markdown]
# ## Number of Characters in Document

# %%
def count_characters(text):
    character_count = len(text)
    return character_count

char_counts = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    char_count = count_characters(text)
    char_counts.append(char_count)
df.insert(6,"Total Chars", char_counts)
print (df)
df.to_csv("new_output.csv")
# Out:
#                                                     0           File Name  \
# 0   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output1.txt
# 1   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output2.txt
# 2   https://docs.netapp.com/us-en/bluexp-reports/l...   files/output3.txt
# 3   https://docs.netapp.com/us-en/bluexp-reports/r...   files/output4.txt
# 4   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output5.txt
# 5   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output6.txt
# 6   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output7.txt
# 7   https://docs.netapp.com/us-en/bluexp-reports/u...   files/output8.txt
# 8   https://docs.netapp.com/us-en/bluexp-reports/u...   files/output9.txt
# 9   https://docs.netapp.com/us-en/bluexp-reports/u...  files/output10.txt
# 10  https://docs.netapp.com/us-en/bluexp-reports/u...  files/output11.txt
# 11  https://docs.netapp.com/us-en/bluexp-reports/u...  files/output12.txt
# 12  https://docs.netapp.com/us-en/bluexp-reports//...  files/output13.txt
# 13  https://docs.netapp.com/us-en/bluexp-reports/g...  files/output14.txt
# 14  https://docs.netapp.com/us-en/bluexp-reports/s...  files/output15.txt
# 15  https://docs.netapp.com/us-en/bluexp-reports/s...  files/output16.txt
# 16  https://docs.netapp.com/us-en/bluexp-reports/r...  files/output17.txt
#
#     Total Words  Unique Words  Total Sentence  Total Chars  Long Words  \
# 0           136            77              11          904          67
# 1           124            81               9          825          54
# 2            68            50               3          502          44
# 3           435           205              30         2726         173
# 4             8             7               1           85           8
# 5            37            25               2          276          23
# 6          1052           462              60         6567         402
# 7          1227           424              68         7959         530
# 8            80            54               4          555          39
# 9           203           131              10         1415         102
# 10           84            67               3          805          47
# 11           32            28               1          247          17
# 12          150            94              12          944          66
# 13           87            60               4          629          48
# 14           66            53               8          458          32
# 15          279           135              22         1737         123
# 16           95            58               7          585          43
#
#     Total Syllables
# 0               229
# 1               227
# 2               127
# 3               748
# 4                15
# 5                69
# 6              1776
# 7              2138
# 8               132
# 9               374
# 10              203
# 11               65
# 12              239
# 13              170
# 14              109
# 15              464
# 16              156

# %% [markdown]
# ## Number of Long Words in Document
# Any words >6 chars in length

# %%
def long_words_in_doc(text):
    long_word_count = 0
    for word in text.split():
        if len(word) >= 6:
            long_word_count += 1
    return long_word_count

long_word_counts = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    long_word_count = long_words_in_doc(text)
    long_word_counts.append(long_word_count)
df.insert(7,"Long Words", long_word_counts)
df.to_csv("new_output.csv")
# Out:
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Frequently
# questions
# BlueXP
# migration
# reports
# 05/30/2023
# you’re
# looking
# answer
# question.
# Access
# BlueXP
# migration
# reports
# service
# What’s
# BlueXP
# migration
# reports
# service
# browser,
# enter:
# https://console.bluexp.netapp.com/
# access
# BlueXP
# console.
# BlueXP
# migration
# reports?
# BlueXP
# migration
# reports
# service
# require
# BlueXP
# migration
# reports
# option
# automatically
# enabled
# BlueXP
# navigation.
# broker?
# BlueXP
# (Cloud
# Sync),
# broker.
# However,
# BlueXP
# migration
# reports
# service
# require
# broker.
# Licensing
# license
# BlueXP
# migration
# reports?
# NetApp
# License
# required.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Enable
# report
# notifications
# 05/30/2023
# BlueXP
# migration
# reports
# service,
# notification
# appears
# BlueXP
# notifications
# BlueXP
# notifications
# report
# generated.
# select
# "Info"
# notification
# setting.
# BlueXP
# select
# Storage
# Canvas.
# notifications,
# select
# notifications
# right.
# enable
# notification,
# following:
# Select
# Settings
# option
# select
# Alerts
# Notification
# Settings.
# Select
# Additional
# Recipients
# Notifications
# column,
# expand
# selecting
# arrow.
# notification
# level,
# select
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Reports
# overview
# 06/05/2023
# BlueXP
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# links,
# links,
# breadth
# system
# trees,
# largest
# files,
# storage
# landscape.
# BlueXP
# migration
# reports
# service
# display
# volumes.
# BlueXP
# migration
# reports,
# accomplish
# goals:
# Create
# report
# Enable
# notifications
# Delete
# report
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# sample
# report
# Volumes
# report
# 05/30/2023
# sample
# Volumes
# report
# showing.
# BlueXP
# select
# Storage
# Migration
# reports.
# display
# report,
# select
# Actions
# option
# select
# Report.
# columns
# information.
# report
# format,
# select
# Actions
# option
# select
# report
# information:
# Maximum
# Depth:
# greatest
# number
# subdirectories
# nested
# within
# directory
# volume.
# example,
# directory/subdirectory/subdirectory2,
# Maximum
# Maximum
# Width:
# greatest
# number
# volume’s
# directories.
# subdirectory,
# symbolic
# Maximum
# Longest
# longest
# subdirectory
# volume.
# Maximum
# Directories:
# number
# directories
# largest
# directory.
# Maximum
# Files:
# number
# largest
# directory.
# another
# directory
# files,
# largest
# directory
# Access
# accessed.
# Change
# metadata,
# example,
# permissions,
# accessed.
# Modify
# content
# modified.
# Failure
# Reasons:
# reasons
# during
# volume
# example,
# report
# contain
# errors
# related
# nonexistent
# incorrect
# access
# permissions
# missing
# files.
# impact
# entire
# directories.
# errors,
# address
# issues
# report
# again.
# Directories
# Files:
# directories
# having
# largest
# number
# directories
# largest
# volume.
# return
# Reports
# Dashboard,
# select
# Reports
# breadcrumbs.
# Reports
# Distribution
# information
# changed
# report
# another.
# Reports
# Distribution
# charts.
# Reports
# Distribution
# information
# available
# completed
# reports
# completed
# reports.
# BlueXP
# select
# Storage
# Migration
# reports.
# Select
# report.
# Actions
# right,
# select
# Reports
# Distribution.
# Reports
# distribution:
# Distribution
# (Total
# Size):
# volume
# different
# dates.
# Distribution
# (Total
# Items):
# number
# files,
# folders,
# links,
# directories
# different
# dates.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Search
# results
# search
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports
# 05/30/2023
# configure
# BlueXP
# migration
# reports
# service.
# BlueXP
# migration
# reports
# option
# automatically
# enabled
# appears
# BlueXP
# navigation.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# 04/25/2023
# NetApp
# provides
# support
# BlueXP
# services
# variety
# Extensive
# self-support
# options
# available
# knowledgebase
# articles
# community
# forum.
# support
# registration
# includes
# remote
# technical
# support
# ticketing.
# self-support
# options
# options
# available
# Documentation
# BlueXP
# documentation
# you’re
# currently
# viewing.
# Knowledge
# Search
# through
# BlueXP
# knowledge
# helpful
# articles
# troubleshoot
# issues.
# Communities
# BlueXP
# community
# follow
# ongoing
# discussions
# create
# Feedback
# input.
# Submit
# feedback
# improve
# BlueXP.
# Create
# NetApp
# support
# addition
# self-support
# options
# above,
# NetApp
# Support
# specialist
# resolve
# issues
# activate
# support.
# Before
# started
# Create
# capability,
# associate
# NetApp
# Support
# credentials
# BlueXP
# login.
# manage
# credentials
# associated
# BlueXP
# login.
# you’re
# opening
# system
# serial
# number,
# account
# associated
# serial
# number
# system.
# BlueXP,
# Support.
# Resources
# choose
# available
# options
# Technical
# Support:
# someone
# phone.
# You’ll
# directed
# netapp.com
# numbers
# Create
# ticket
# NetApp
# Support
# specialist:
# NetApp
# Support
# Account:
# Select
# applicable
# account
# associated
# person
# opening
# support
# person
# primary
# contact
# NetApp
# addition
# additional
# emails
# provided
# below.
# account,
# navigate
# Management
# within
# Support
# section
# BlueXP
# there.
# Service:
# Select
# service
# associated
# example,
# BlueXP
# specific
# technical
# support
# workflows
# functionality
# within
# service.
# Working
# Environment:
# applicable
# storage,
# select
# Volumes
# On-Prem
# associated
# working
# environment.
# working
# environments
# within
# BlueXP
# account,
# workspace,
# Connector
# selected
# banner
# service.
# Priority:
# Choose
# priority
# Medium,
# Critical.
# details
# priorities,
# information
# Description:
# Provide
# detailed
# description
# problem,
# including
# applicable
# messages
# troubleshooting
# performed.
# Additional
# Addresses:
# additional
# addresses
# someone
# issue.
# Attachment
# (Optional):
# Upload
# attachments,
# Attachments
# limited
# following
# extensions
# supported:
# jpg/jpeg,
# doc/docx,
# xls/xlsx,
# finish
# pop-up
# appear
# support
# number.
# NetApp
# Support
# specialist
# review
# history
# support
# cases,
# Settings
# Timeline
# actions
# "create
# support
# case."
# button
# expand
# action
# details.
# possible
# encounter
# following
# message
# trying
# create
# authorized
# Create
# against
# selected
# service"
# account
# company
# record
# associated
# company
# record
# BlueXP
# account
# serial
# number
# 960xxxx)
# working
# environment
# serial
# number.
# assistance
# following
# options:
# in-product
# Submit
# non-technical
# https://mysupport.netapp.com/site/help
# Manage
# support
# (Preview)
# manage
# active
# resolved
# support
# directly
# BlueXP.
# manage
# associated
# account
# company.
# management
# available
# Preview.
# refine
# experience
# enhancements
# upcoming
# releases.
# Please
# feedback
# in-product
# following:
# management
# dashboard
# offers
# views:
# opened
# months
# account
# provided.
# opened
# months
# company
# account.
# results
# reflect
# related
# selected.
# remove
# columns
# interest
# filter
# contents
# columns
# Priority
# Status.
# columns
# provide
# sorting
# capabilities.
# details.
# per-case
# level,
# ability
# update
# already
# Closed
# Pending
# Closed
# status.
# BlueXP,
# Support.
# Management
# you’re
# prompted,
# account
# BlueXP.
# management
# related
# account
# associated
# BlueXP
# account.
# account
# appears
# management
# Optionally
# modify
# information
# displays
# table:
# Organization’s
# cases,
# associated
# company.
# Modify
# choosing
# choosing
# different
# frame.
# Filter
# contents
# columns.
# Change
# columns
# appear
# clicking
# choosing
# columns
# display.
# Manage
# existing
# clicking
# selecting
# available
# options:
# details
# specific
# Update
# notes:
# Provide
# additional
# details
# problem
# select
# Upload
# attach
# maximum
# files.
# Attachments
# limited
# following
# extensions
# supported:
# jpg/jpeg,
# doc/docx,
# xls/xlsx,
# Provide
# details
# you’re
# closing
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Register
# support
# 04/25/2023
# Support
# registration
# required
# BlueXP
# account
# individual
# Volumes
# systems.
# Support
# registration
# overview
# registration
# activate
# support
# entitlement:
# Registering
# BlueXP
# account
# support
# subscription
# 960xxxxxxxxx
# serial
# number
# located
# Support
# Resources
# BlueXP).
# serves
# single
# support
# subscription
# service
# within
# BlueXP.
# BlueXP
# account-level
# support
# subscription
# registered.
# Registering
# Volumes
# serial
# numbers
# associated
# subscription
# provider’s
# marketplace
# (these
# 909201xxxxxxxx
# serial
# numbers).
# serial
# numbers
# commonly
# referred
# serial
# numbers
# generated
# BlueXP
# Volumes
# deployment.
# Registering
# serial
# numbers
# enables
# capabilities
# opening
# support
# tickets
# automatic
# generation.
# Registration
# completed
# adding
# NetApp
# Support
# accounts
# BlueXP
# described
# below.
# Support
# provider
# solutions
# technical
# support
# following
# provider
# solutions,
# "Getting
# BlueXP
# documentation
# product.
# Amazon
# NetApp
# Volumes
# Service
# Google
# Register
# BlueXP
# account
# NetApp
# support
# register
# support
# activate
# support
# entitlement,
# BlueXP
# account
# associate
# NetApp
# Support
# account
# BlueXP
# login.
# register
# NetApp
# support
# depends
# whether
# already
# NetApp
# Support
# account.
# Existing
# customer
# account
# you’re
# NetApp
# customer
# account,
# simply
# register
# support
# through
# BlueXP.
# BlueXP
# console,
# Settings
# select
# Credentials.
# Credentials.
# Select
# credentials
# follow
# NetApp
# Support
# Authentication
# prompt.
# confirm
# registration
# process
# successful,
# select
# Support.
# Resources
# should
# account
# registered
# support.
# BlueXP
# support
# registration
# status
# associated
# NetApp
# Support
# account
# BlueXP
# login.
# However,
# doesn’t
# BlueXP
# account
# registered
# support.
# account
# followed
# steps,
# account
# registered.
# Existing
# customer
# account
# you’re
# existing
# NetApp
# customer
# existing
# licenses
# serial
# numbers
# account,
# create
# account
# associate
# BlueXP
# login.
# Create
# NetApp
# Support
# account
# completing
# NetApp
# Support
# Registration
# select
# appropriate
# Level,
# typically
# NetApp
# Customer/End
# BlueXP
# account
# serial
# number
# (960xxxx)
# serial
# number
# field.
# account
# processing.
# Associate
# account
# BlueXP
# completing
# Existing
# customer
# account.
# NetApp
# NetApp
# account,
# follow
# below.
# BlueXP
# console,
# select
# Support.
# Locate
# account
# serial
# number
# Support
# Registration
# Navigate
# NetApp’s
# support
# registration
# select
# registered
# NetApp
# Customer.
# mandatory
# fields
# (those
# asterisks).
# Product
# field,
# select
# Manager
# select
# applicable
# billing
# provider.
# account
# serial
# number
# above,
# complete
# security
# check,
# confirm
# NetApp’s
# Global
# Privacy
# Policy.
# immediately
# mailbox
# provided
# finalize
# secure
# transaction.
# folders
# validation
# doesn’t
# arrive
# minutes.
# Confirm
# action
# within
# email.
# Confirming
# submits
# request
# NetApp
# recommends
# create
# NetApp
# Support
# account.
# Create
# NetApp
# Support
# account
# completing
# NetApp
# Support
# Registration
# select
# appropriate
# Level,
# typically
# NetApp
# Customer/End
# account
# serial
# number
# (960xxxx)
# serial
# number
# field.
# account
# processing.
# finish
# NetApp
# should
# during
# process.
# one-time
# onboarding
# exercise
# users.
# NetApp
# Support
# account,
# associate
# account
# BlueXP
# completing
# Existing
# customer
# account.
# Associate
# credentials
# Volumes
# support
# Associating
# NetApp
# Support
# credentials
# BlueXP
# account
# required
# enable
# following
# workflows
# Volumes
# ONTAP:
# Registering
# pay-as-you-go
# Volumes
# systems
# support
# Providing
# account
# required
# activate
# support
# system
# access
# NetApp
# technical
# support
# resources.
# Deploying
# Volumes
# license
# (BYOL)
# Providing
# account
# required
# BlueXP
# upload
# license
# enable
# subscription
# purchased.
# includes
# automatic
# updates
# renewals.
# Upgrading
# Volumes
# software
# latest
# release
# Associating
# credentials
# BlueXP
# account
# different
# account
# associated
# BlueXP
# login.
# credentials
# associated
# specific
# BlueXP
# account
# belong
# BlueXP
# account
# access
# credentials
# Support
# Management.
# customer-level
# account,
# accounts.
# partner
# reseller
# account,
# accounts,
# alongside
# customer-level
# accounts.
# BlueXP
# console,
# select
# Support.
# Management
# Account.
# you’re
# prompted,
# Continue
# redirected
# Microsoft
# NetApp
# Microsoft
# Active
# Directory
# identity
# provider
# authentication
# services
# specific
# support
# licensing.
# provide
# NetApp
# Support
# registered
# address
# password
# perform
# authentication
# process.
# actions
# enable
# BlueXP
# account
# things
# license
# downloads,
# software
# upgrade
# verification,
# future
# support
# registrations.
# following:
# account
# customer-level
# account
# account).
# multiple
# customer-level
# accounts.
# account
# account
# partner-level
# account.
# customer-level
# accounts
# partner-level
# account
# exists,
# you’ll
# following
# message:
# customer
# allowed
# account
# already
# different
# type."
# pre-existing
# customer-level
# accounts
# partner-level
# account.
# successful
# login,
# NetApp
# system-generated
# email.
# Management
# display
# refresh
# credential
# tokens,
# Update
# Credentials
# option
# option
# prompts
# again.
# accounts
# expire
# notification
# posted
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# What’s
# 05/30/2023
# what’s
# BlueXP
# migration
# reports.
# BlueXP
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# links,
# links,
# breadth
# system
# trees,
# largest
# files,
# storage
# landscape.
# information,
# process
# handle
# inventory
# efficiently
# successfully.
# BlueXP
# migration
# reports.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports
# 05/30/2023
# preparing
# migrate,
# system
# determine
# BlueXP
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# links,
# links,
# breadth
# system
# trees,
# largest
# files,
# storage
# landscape.
# information,
# process
# handle
# inventory
# efficiently
# successfully.
# BlueXP
# migration
# reports
# service
# information
# working
# environments.
# Benefits
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports
# service
# offers
# following
# benefits:
# Provides
# simple
# process
# obtain
# protection
# status
# working
# environment
# Offers
# storage
# landscape
# Reduces
# identifying
# additional
# storage
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports,
# accomplish
# following:
# Create
# reports.
# Identify
# changed
# report
# another
# Reports
# Distribution
# charts.
# Enable
# notifications
# report
# generation.
# Delete
# reports.
# NetApp
# doesn’t
# charge
# service.
# Licensing
# NetApp
# License
# required.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# notices
# 04/24/2023
# notices
# provide
# access
# copyright
# statements,
# trademarks,
# patents,
# Copyright
# http://www.netapp.com/us/legal/copyright.aspx
# Trademarks
# NETAPP,
# NETAPP
# listed
# NetApp
# Trademarks
# trademarks
# NetApp,
# company
# product
# trademarks
# respective
# owners.
# http://www.netapp.com/us/legal/netapptmlist.aspx
# Patents
# current
# NetApp
# patents
# https://www.netapp.com/us/media/patents-page.pdf
# Privacy
# policy
# https://www.netapp.com/us/legal/privacypolicy/index.aspx
# source
# Notice
# provide
# information
# third-party
# copyright
# licenses
# NetApp
# software.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Limitations
# 04/25/2023
# limitations
# identify
# platforms,
# devices,
# functions
# supported
# release
# service,
# interoperate
# correctly
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Access
# BlueXP
# migration
# reports
# 05/30/2023
# BlueXP
# accessible
# browser
# through
# BlueXP
# SaaS-based
# interface.
# BlueXP,
# NetApp
# Support
# credentials
# NetApp
# password.
# logging
# browser
# BlueXP
# console.
# NetApp
# BlueXP
# appears.
# BlueXP.
# following:
# BlueXP
# navigation,
# select
# Storage
# Migration
# reports.
# BlueXP
# Canvas,
# select
# working
# environment.
# panel,
# select
# Reports
# Cluster
# Reports.
# generated
# reports,
# landing
# appears.
# generated
# reports,
# report
# listing
# appears.
# selected
# specific
# cluster
# BlueXP
# Canvas
# panel,
# reports
# filtered
# cluster.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports
# prerequisites
# 05/30/2023
# started
# verifying
# readiness
# operational
# environment,
# login,
# network
# access,
# browser.
# BlueXP
# migration
# reports
# service
# following
# prerequisites:
# Access
# Volumes
# NetApp
# Files,
# Amazon
# NetApp
# ONTAP,
# on-premises
# working
# environments
# BlueXP
# Connector
# NetApp
# BlueXP
# management
# BlueXP
# documentation
# configure
# BlueXP
# Connector.
# Standard
# BlueXP
# requirements
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# BlueXP
# migration
# reports
# 05/30/2023
# Here’s
# overview
# needed
# started
# BlueXP
# migration
# reports.
# within
# provides
# details.
# Review
# prerequisites
# Ensure
# environment
# requirements.
# What’s
# Here’s
# Create
# report.
# report
# sample.
# Delete
# report.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Create
# report
# 05/30/2023
# create
# volumes
# report
# number
# files,
# directories,
# symbolic
# links,
# links,
# largest
# sizes,
# create
# report,
# BlueXP
# migration
# reports
# service
# compiles
# report
# definition,
# multiple
# instances
# report.
# BlueXP
# migration
# reports
# service
# volumes.
# generate
# report
# download
# report
# BlueXP
# migration
# reports
# operations
# listed
# BlueXP
# Timeline.
# Timeline,
# select
# BlueXP
# Settings
# Timeline.
# BlueXP
# select
# Storage
# Migration
# reports.
# Select
# Create
# Report.
# report
# Select
# working
# environment
# drop-down
# environments
# active
# enabled
# BlueXP
# appear
# working
# environments.
# BlueXP
# Connector
# access
# volume
# access
# enable
# environment,
# Connectors
# BlueXP
# documentation.
# Search
# search
# volume
# report
# choose
# Select
# volume.
# Select
# Create
# report.
# BlueXP
# migration
# reports
# service
# generates
# report
# reports
# display
# report,
# select
# Actions
# option
# select
# Report.
# download
# report,
# select
# Actions
# option
# select
# Download
# Report.
# generate
# another
# instance
# report,
# select
# report
# right,
# select
# report.
# docs.netapp.com
# BlueXP
# BlueXP
# migration
# reports
# Delete
# report
# 05/30/2023
# delete
# report
# contained
# longer
# report.
# delete
# instances
# report.
# BlueXP
# select
# Storage
# Migration
# reports.
# Reports
# Dashboard,
# select
# report.
# report
# select
# Actions
# select
# Delete
# Report.
# multiple
# instances
# report
# exist,
# select
# delete
# select
# Delete.
# Select
# Delete
# confirm
# deletion.
#                                                     0           File Name  \
# 0   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output1.txt
# 1   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output2.txt
# 2   https://docs.netapp.com/us-en/bluexp-reports/l...   files/output3.txt
# 3   https://docs.netapp.com/us-en/bluexp-reports/r...   files/output4.txt
# 4   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output5.txt
# 5   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output6.txt
# 6   https://docs.netapp.com/us-en/bluexp-reports/g...   files/output7.txt
# 7   https://docs.netapp.com/us-en/bluexp-reports/u...   files/output8.txt
# 8   https://docs.netapp.com/us-en/bluexp-reports/u...   files/output9.txt
# 9   https://docs.netapp.com/us-en/bluexp-reports/u...  files/output10.txt
# 10  https://docs.netapp.com/us-en/bluexp-reports/u...  files/output11.txt
# 11  https://docs.netapp.com/us-en/bluexp-reports/u...  files/output12.txt
# 12  https://docs.netapp.com/us-en/bluexp-reports//...  files/output13.txt
# 13  https://docs.netapp.com/us-en/bluexp-reports/g...  files/output14.txt
# 14  https://docs.netapp.com/us-en/bluexp-reports/s...  files/output15.txt
# 15  https://docs.netapp.com/us-en/bluexp-reports/s...  files/output16.txt
# 16  https://docs.netapp.com/us-en/bluexp-reports/r...  files/output17.txt
#
#     Total Words  Unique Words  Total Sentence  Long Words  Total Syllables
# 0           136            77              11          67              229
# 1           124            81               9          54              227
# 2            68            50               3          44              127
# 3           435           205              30         173              748
# 4             8             7               1           8               15
# 5            37            25               2          23               69
# 6          1052           462              60         402             1776
# 7          1227           424              68         530             2138
# 8            80            54               4          39              132
# 9           203           131              10         102              374
# 10           84            67               3          47              203
# 11           32            28               1          17               65
# 12          150            94              12          66              239
# 13           87            60               4          48              170
# 14           66            53               8          32              109
# 15          279           135              22         123              464
# 16           95            58               7          43              156

# %% [markdown]
# ## Number of Blank Spaces

# %%
def count_blanks(text):
    blank_count = 0
    for char in text:
        if char.isspace():
            blank_count += 1
    return blank_count

blank_counts = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    blank_count = count_blanks(text)
    blank_counts.append(blank_count)
df.insert(8,"Blanks", blank_counts)
df.to_csv("new_output.csv")

# %% [markdown]
# ## Number of Words with More Than 2 Syllables

# %%
# Function to count syllables in a word
def count_syllables(word):
    syllable_count = syllables.estimate(word.strip())
    return syllable_count

# Function to count syllables in a document
def count_two_syllables_in_document(content):
    words = content.split()
    ctr = 0
    for word in words:
        if count_syllables(word) > 1:
            ctr += 1
    return ctr

two_syl_counts = []
file_list = os.listdir("./files/")
for file in file_list:
    text = open(f"./files/{file}").read()
    two_syl_count = count_two_syllables_in_document(text)
    two_syl_counts.append(two_syl_count)
df.insert(8,">2 Syl Words", two_syl_counts)
df.to_csv("new_output.csv")
# Out:
# docs.netapp.com
# migration
# reports
# Frequently
# asked
# questions
# migration
# reports
# you’re
# looking
# answer
# question.
# Access
# migration
# reports
# service
# migration
# reports
# service
# browser,
# enter:
# https://console.bluexp.netapp.com/
# access
# console.
# migration
# reports?
# migration
# reports
# service
# require
# any
# migration
# reports
# option
# automatically
# enabled
# navigation.
# data
# broker?
# copy
# data
# broker.
# However,
# migration
# reports
# service
# require
# data
# broker.
# Licensing
# license
# use
# migration
# reports?
# NetApp
# License
# required.
# docs.netapp.com
# migration
# reports
# Enable
# report
# notifications
# migration
# reports
# service,
# notification
# appears
# notifications
# page.
# also
# notifications
# alert
# users
# email
# report
# generated.
# select
# "Info"
# notification
# setting.
# select
# Storage
# Canvas.
# notifications,
# select
# notifications
# icon
# upper
# enable
# email
# notification,
# following:
# Select
# Settings
# option
# select
# Alerts
# Notification
# Settings.
# Select
# Additional
# Recipients
# Notifications
# column,
# expand
# selecting
# arrow.
# notification
# level,
# select
# Info.
# docs.netapp.com
# migration
# reports
# Reports
# overview
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# system
# largest
# files,
# storage
# landscape.
# migration
# reports
# service
# display
# data
# volumes.
# Using
# migration
# reports,
# accomplish
# these
# Create
# report
# Enable
# notifications
# Delete
# report
# docs.netapp.com
# migration
# reports
# sample
# report
# Volumes
# report
# sample
# Volumes
# report
# data
# showing.
# select
# Storage
# Migration
# reports.
# display
# report,
# select
# Actions
# option
# select
# Report.
# columns
# hover
# over
# information.
# report
# format,
# select
# Actions
# option
# select
# report
# information:
# Maximum
# Total
# greatest
# number
# subdirectories
# nested
# within
# directory
# volume.
# example,
# directory/subdirectory/subdirectory2,
# Maximum
# Total
# Maximum
# greatest
# number
# items
# volume’s
# directories.
# item
# file,
# subdirectory,
# symbolic
# Maximum
# Longest
# longest
# subdirectory
# volume.
# Maximum
# Directories:
# number
# directories
# largest
# directory.
# Maximum
# Files:
# number
# files
# largest
# directory.
# There
# another
# directory
# files,
# largest
# directory
# Access
# Time:
# times
# files
# were
# accessed.
# Change
# Time:
# metadata,
# example,
# permissions,
# accessed.
# Modify
# Time:
# times
# content
# files
# modified.
# Failure
# Reasons:
# error
# reasons
# during
# volume
# example,
# report
# contain
# errors
# related
# nonexistent
# incorrect
# access
# permissions
# missing
# files.
# type
# error
# impact
# entire
# files
# directories.
# After
# errors,
# address
# issues
# report
# again.
# Directories
# Files:
# directories
# having
# largest
# number
# directories
# largest
# sizes
# volume.
# return
# Reports
# Dashboard,
# select
# Reports
# breadcrumbs.
# Reports
# Distribution
# information
# data
# changed
# one
# report
# another.
# using
# Reports
# Distribution
# Reports
# Distribution
# information
# available
# only
# completed
# reports
# only
# there
# are
# completed
# reports.
# select
# Storage
# Migration
# reports.
# Select
# report.
# Actions
# menu
# select
# Reports
# Distribution.
# Reports
# distribution:
# Distribution
# Over
# (Total
# Size):
# volume
# different
# dates.
# Distribution
# Over
# (Total
# Items):
# number
# files,
# folders,
# directories
# different
# dates.
# docs.netapp.com
# migration
# reports
# results
# docs.netapp.com
# migration
# reports
# migration
# reports
# configure
# migration
# reports
# service.
# migration
# reports
# option
# automatically
# enabled
# appears
# navigation.
# docs.netapp.com
# migration
# reports
# NetApp
# provides
# support
# services
# variety
# Extensive
# self-support
# options
# are
# available
# knowledgebase
# articles
# community
# forum.
# support
# registration
# includes
# remote
# technical
# support
# ticketing.
# Use
# self-support
# options
# These
# options
# are
# available
# Documentation
# documentation
# you’re
# currently
# viewing.
# Knowledge
# knowledge
# helpful
# articles
# troubleshoot
# issues.
# Communities
# community
# follow
# ongoing
# discussions
# create
# ones.
# Feedback
# email
# value
# input.
# Submit
# feedback
# improve
# Create
# NetApp
# support
# addition
# self-support
# options
# above,
# NetApp
# Support
# specialist
# resolve
# any
# issues
# after
# activate
# support.
# Before
# started
# use
# Create
# capability,
# associate
# NetApp
# Support
# credentials
# login.
# manage
# credentials
# associated
# login.
# you’re
# opening
# ONTAP
# system
# serial
# number,
# account
# associated
# serial
# number
# system.
# Support.
# Resources
# page,
# choose
# one
# available
# options
# under
# Technical
# Support:
# someone
# phone.
# directed
# netapp.com
# phone
# numbers
# Create
# open
# ticket
# NetApp
# Support
# specialist:
# NetApp
# Support
# Account:
# Select
# applicable
# account
# associated
# person
# opening
# support
# case.
# person
# primary
# contact
# NetApp
# addition
# additional
# emails
# provided
# below.
# account,
# navigate
# Management
# within
# Support
# section
# there.
# Service:
# Select
# service
# issue
# associated
# example,
# specific
# technical
# support
# issue
# workflows
# functionality
# within
# service.
# Working
# Environment:
# applicable
# storage,
# select
# Volumes
# ONTAP
# On-Prem
# associated
# working
# environment.
# working
# environments
# are
# within
# scope
# account,
# workspace,
# Connector
# selected
# banner
# service.
# Priority:
# Choose
# priority
# case,
# Medium,
# Critical.
# details
# about
# these
# priorities,
# hover
# mouse
# over
# information
# icon
# name.
# Issue
# Description:
# Provide
# detailed
# description
# problem,
# including
# any
# applicable
# error
# messages
# troubleshooting
# performed.
# Additional
# Email
# Addresses:
# Enter
# additional
# email
# addresses
# someone
# else
# aware
# issue.
# Attachment
# (Optional):
# Upload
# attachments,
# one
# time.
# Attachments
# are
# limited
# file.
# following
# extensions
# are
# supported:
# doc/docx,
# After
# finish
# pop-up
# appear
# support
# number.
# NetApp
# Support
# specialist
# review
# history
# support
# cases,
# Settings
# Timeline
# actions
# named
# "create
# support
# case."
# button
# expand
# action
# details.
# possible
# encounter
# following
# error
# message
# create
# case:
# are
# authorized
# Create
# against
# selected
# service"
# error
# account
# company
# record
# associated
# company
# record
# account
# serial
# number
# working
# environment
# serial
# number.
# assistance
# using
# one
# following
# options:
# Use
# in-product
# Submit
# non-technical
# https://mysupport.netapp.com/site/help
# Manage
# support
# cases
# (Preview)
# manage
# active
# resolved
# support
# cases
# directly
# manage
# cases
# associated
# account
# company.
# management
# available
# Preview.
# refine
# experience
# enhancements
# upcoming
# releases.
# Please
# feedback
# using
# in-product
# following:
# management
# dashboard
# offers
# total
# cases
# opened
# user
# account
# provided.
# total
# cases
# opened
# company
# level
# based
# user
# account.
# results
# table
# reflect
# cases
# related
# selected.
# remove
# columns
# interest
# filter
# contents
# columns
# Priority
# Status.
# Other
# columns
# provide
# sorting
# capabilities.
# below
# details.
# per-case
# level,
# offer
# ability
# update
# notes
# close
# already
# Closed
# Pending
# Closed
# status.
# Support.
# Management
# you’re
# prompted,
# account
# management
# open
# cases
# related
# account
# associated
# user
# account.
# account
# appears
# management
# page.
# Optionally
# modify
# information
# displays
# table:
# Under
# Organization’s
# cases,
# cases
# associated
# company.
# Modify
# range
# choosing
# exact
# range
# choosing
# different
# frame.
# Filter
# contents
# columns.
# Change
# columns
# appear
# table
# clicking
# choosing
# columns
# display.
# Manage
# existing
# clicking
# selecting
# one
# available
# options:
# case:
# details
# about
# specific
# case.
# Update
# notes:
# Provide
# additional
# details
# about
# problem
# select
# Upload
# files
# attach
# maximum
# files.
# Attachments
# are
# limited
# file.
# following
# extensions
# are
# supported:
# doc/docx,
# Close
# case:
# Provide
# details
# about
# you’re
# closing
# Close
# case.
# docs.netapp.com
# migration
# reports
# Register
# support
# Support
# registration
# required
# account
# individual
# Volumes
# ONTAP
# systems.
# Support
# registration
# overview
# There
# are
# registration
# activate
# support
# entitlement:
# Registering
# account
# support
# subscription
# digit
# serial
# number
# located
# Support
# Resources
# serves
# single
# support
# subscription
# any
# service
# within
# account-level
# support
# subscription
# registered.
# Registering
# Volumes
# ONTAP
# serial
# numbers
# associated
# subscription
# provider’s
# marketplace
# (these
# are
# digit
# serial
# numbers).
# These
# serial
# numbers
# are
# commonly
# referred
# PAYGO
# serial
# numbers
# generated
# Volumes
# ONTAP
# deployment.
# Registering
# types
# serial
# numbers
# enables
# capabilities
# opening
# support
# tickets
# automatic
# generation.
# Registration
# completed
# adding
# NetApp
# Support
# accounts
# described
# below.
# Support
# provider
# solutions
# technical
# support
# following
# provider
# solutions,
# refer
# "Getting
# documentation
# product.
# Amazon
# ONTAP
# Azure
# NetApp
# Files
# Volumes
# Service
# Google
# Register
# account
# NetApp
# support
# register
# support
# activate
# support
# entitlement,
# one
# user
# account
# associate
# NetApp
# Support
# account
# login.
# register
# NetApp
# support
# depends
# whether
# already
# NetApp
# Support
# account.
# Existing
# customer
# account
# you’re
# NetApp
# customer
# account,
# simply
# register
# support
# upper
# console,
# Settings
# icon,
# select
# Credentials.
# User
# Credentials.
# Select
# credentials
# follow
# NetApp
# Support
# Authentication
# confirm
# registration
# process
# successful,
# icon,
# select
# Support.
# Resources
# account
# registered
# support.
# other
# users
# support
# registration
# status
# associated
# NetApp
# Support
# account
# login.
# However,
# account
# registered
# support.
# one
# user
# account
# followed
# these
# account
# registered.
# Existing
# customer
# account
# you’re
# existing
# NetApp
# customer
# existing
# licenses
# serial
# numbers
# account,
# create
# account
# associate
# login.
# Create
# NetApp
# Support
# account
# completing
# NetApp
# Support
# User
# Registration
# select
# appropriate
# User
# Level,
# typically
# NetApp
# Customer/End
# User.
# copy
# account
# serial
# number
# above
# serial
# number
# account
# processing.
# Associate
# account
# login
# completing
# under
# Existing
# customer
# account.
# NetApp
# are
# NetApp
# account,
# follow
# below.
# upper
# console,
# icon,
# select
# Support.
# Locate
# account
# serial
# number
# Support
# Registration
# page.
# Navigate
# NetApp’s
# support
# registration
# select
# registered
# NetApp
# Customer.
# mandatory
# (those
# asterisks).
# Product
# select
# Manager
# select
# applicable
# billing
# provider.
# Copy
# account
# serial
# number
# above,
# complete
# security
# confirm
# NetApp’s
# Global
# Data
# Privacy
# Policy.
# email
# immediately
# mailbox
# provided
# finalize
# secure
# transaction.
# folders
# validation
# email
# arrive
# minutes.
# Confirm
# action
# within
# email.
# Confirming
# submits
# request
# NetApp
# recommends
# create
# NetApp
# Support
# account.
# Create
# NetApp
# Support
# account
# completing
# NetApp
# Support
# User
# Registration
# select
# appropriate
# User
# Level,
# typically
# NetApp
# Customer/End
# User.
# copy
# account
# serial
# number
# above
# serial
# number
# account
# processing.
# After
# finish
# NetApp
# during
# process.
# one-time
# onboarding
# exercise
# users.
# NetApp
# Support
# account,
# associate
# account
# login
# completing
# under
# Existing
# customer
# account.
# Associate
# credentials
# Volumes
# ONTAP
# support
# Associating
# NetApp
# Support
# credentials
# account
# required
# enable
# following
# workflows
# Volumes
# ONTAP:
# Registering
# pay-as-you-go
# Volumes
# ONTAP
# systems
# support
# Providing
# account
# required
# activate
# support
# system
# access
# NetApp
# technical
# support
# resources.
# Deploying
# Volumes
# ONTAP
# license
# Providing
# account
# required
# upload
# license
# enable
# subscription
# purchased.
# includes
# automatic
# updates
# renewals.
# Upgrading
# Volumes
# ONTAP
# software
# latest
# release
# Associating
# credentials
# account
# different
# account
# associated
# user
# login.
# These
# credentials
# are
# associated
# specific
# account
# Users
# belong
# account
# access
# these
# credentials
# Support
# Management.
# customer-level
# account,
# one
# accounts.
# partner
# reseller
# account,
# one
# accounts,
# added
# alongside
# customer-level
# accounts.
# upper
# console,
# icon,
# select
# Support.
# Management
# Account.
# you’re
# prompted,
# Continue
# redirected
# Microsoft
# login
# page.
# NetApp
# uses
# Microsoft
# Azure
# Active
# Directory
# identity
# provider
# authentication
# services
# specific
# support
# licensing.
# login
# page,
# provide
# NetApp
# Support
# registered
# email
# address
# password
# perform
# authentication
# process.
# These
# actions
# enable
# use
# account
# license
# downloads,
# software
# upgrade
# verification,
# future
# support
# registrations.
# following:
# account
# customer-level
# account
# account).
# multiple
# customer-level
# accounts.
# There
# only
# one
# account
# account
# partner-level
# account.
# customer-level
# accounts
# partner-level
# account
# exists,
# following
# error
# message:
# customer
# type
# allowed
# account
# there
# are
# already
# Users
# different
# type."
# pre-existing
# customer-level
# accounts
# partner-level
# account.
# Upon
# successful
# login,
# NetApp
# store
# user
# name.
# system-generated
# email.
# Management
# page,
# display
# email
# menu.
# ever
# refresh
# login
# credential
# tokens,
# there
# also
# Update
# Credentials
# option
# menu.
# Using
# option
# again.
# token
# these
# accounts
# expire
# after
# notification
# posted
# alert
# docs.netapp.com
# migration
# reports
# migration
# reports.
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# system
# largest
# files,
# storage
# landscape.
# information,
# ahead
# process
# use
# handle
# inventory
# efficiently
# successfully.
# about
# migration
# reports.
# docs.netapp.com
# migration
# reports
# about
# migration
# reports
# are
# preparing
# move,
# migrate,
# clone
# system
# data,
# determine
# have.
# migration
# reports
# service,
# quickly
# identify
# number
# files,
# directories,
# symbolic
# system
# largest
# files,
# storage
# landscape.
# information,
# ahead
# process
# use
# handle
# inventory
# efficiently
# successfully.
# migration
# reports
# service
# information
# working
# environments.
# Benefits
# migration
# reports
# migration
# reports
# service
# offers
# following
# benefits:
# Provides
# simple
# process
# obtain
# data
# protection
# status
# working
# environment
# Offers
# storage
# landscape
# Reduces
# identifying
# additional
# storage
# migration
# reports
# Using
# migration
# reports,
# accomplish
# following:
# Create
# reports.
# Identify
# data
# changed
# one
# report
# another
# using
# Reports
# Distribution
# Enable
# email
# notifications
# about
# report
# generation.
# Delete
# reports.
# NetApp
# charge
# using
# service.
# Licensing
# NetApp
# License
# required.
# docs.netapp.com
# migration
# reports
# Legal
# notices
# Legal
# notices
# provide
# access
# copyright
# statements,
# trademarks,
# patents,
# more.
# Copyright
# http://www.netapp.com/us/legal/copyright.aspx
# Trademarks
# NETAPP,
# NETAPP
# logo,
# listed
# NetApp
# Trademarks
# are
# trademarks
# NetApp,
# Other
# company
# product
# names
# trademarks
# respective
# owners.
# http://www.netapp.com/us/legal/netapptmlist.aspx
# Patents
# current
# NetApp
# owned
# patents
# https://www.netapp.com/us/media/patents-page.pdf
# Privacy
# policy
# https://www.netapp.com/us/legal/privacypolicy/index.aspx
# Open
# source
# Notice
# files
# provide
# information
# about
# third-party
# copyright
# licenses
# NetApp
# software.
# docs.netapp.com
# migration
# reports
# Limitations
# limitations
# identify
# platforms,
# devices,
# functions
# are
# supported
# release
# service,
# interoperate
# correctly
# docs.netapp.com
# migration
# reports
# Access
# migration
# reports
# accessible
# browser
# SaaS-based
# user
# interface.
# use
# NetApp
# Support
# credentials
# NetApp
# login
# using
# email
# password.
# about
# logging
# Open
# browser
# console.
# NetApp
# login
# appears.
# one
# following:
# navigation,
# select
# Storage
# Migration
# reports.
# Canvas,
# select
# working
# environment.
# panel,
# select
# Reports
# Cluster
# Reports.
# generated
# any
# reports,
# landing
# appears.
# generated
# reports,
# report
# listing
# appears.
# selected
# specific
# cluster
# Canvas
# panel,
# reports
# are
# filtered
# only
# cluster.
# docs.netapp.com
# migration
# reports
# migration
# reports
# prerequisites
# started
# verifying
# readiness
# operational
# environment,
# login,
# network
# access,
# browser.
# migration
# reports
# service
# following
# prerequisites:
# Access
# data
# Volumes
# ONTAP
# Azure
# NetApp
# Files,
# Amazon
# NetApp
# ONTAP,
# on-premises
# working
# environments
# Use
# ONTAP
# later
# Connector
# NetApp
# management
# Refer
# documentation
# configure
# Connector.
# Standard
# requirements
# docs.netapp.com
# migration
# reports
# migration
# reports
# Here’s
# overview
# needed
# started
# migration
# reports.
# within
# provides
# details.
# Review
# prerequisites
# Ensure
# environment
# these
# requirements.
# Here’s
# Create
# report.
# report
# sample.
# Delete
# report.
# docs.netapp.com
# migration
# reports
# Create
# report
# create
# volumes
# report
# number
# files,
# files
# directories,
# symbolic
# largest
# sizes,
# more.
# create
# report,
# migration
# reports
# service
# compiles
# data.
# Using
# report
# definition,
# multiple
# instances
# report.
# migration
# reports
# service
# data
# volumes.
# generate
# only
# one
# report
# time.
# also
# download
# report
# file.
# migration
# reports
# operations
# are
# listed
# Timeline.
# Timeline,
# select
# Settings
# Timeline.
# select
# Storage
# Migration
# reports.
# Select
# Create
# Report.
# Enter
# report
# name.
# Select
# working
# environment
# drop-down
# Only
# those
# environments
# are
# active
# enabled
# appear
# working
# environments.
# Connector
# access
# data
# volume
# order
# access
# data.
# enable
# environment,
# refer
# about
# Connectors
# documentation.
# Using
# icon,
# volume
# report
# choose
# Select
# volume.
# Select
# Create
# report.
# migration
# reports
# service
# generates
# report
# reports
# display
# report,
# select
# Actions
# option
# select
# Report.
# download
# report,
# select
# Actions
# option
# select
# Download
# Report.
# generate
# another
# instance
# report,
# select
# report
# select
# report.
# docs.netapp.com
# migration
# reports
# Delete
# report
# delete
# report
# contained
# error
# fixed
# longer
# report.
# delete
# one
# instances
# report.
# select
# Storage
# Migration
# reports.
# Reports
# Dashboard,
# select
# report.
# report
# select
# Actions
# menu
# select
# Delete
# Report.
# multiple
# instances
# report
# exist,
# select
# those
# delete
# select
# Delete.
# Select
# Delete
# confirm
# deletion.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 22
#      20     two_syl_count = count_two_syllables_in_document(text)
#      21     two_syl_counts.append(two_syl_count)
# ---> 22 df.insert(8,">2 Syl Words", two_syl_counts)
#      23 df.to_csv("new_output.csv")
#
# File c:\Users\nikki\anaconda3\lib\site-packages\pandas\core\frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert >2 Syl Words, already exists

# %% [markdown]
# ## Anderson's Readability Index
# The Rix score is calculated by (number of long words/ number of sentences).
# Long words have more then 6 characters.

# %%
input_file = 'new_output.csv'
output_file = 'scores.csv'

data = pd.read_csv(input_file)
data['RIX'] = round((data['Long Words'] / data['Total Sentence']), 3)
data.to_csv(output_file, index=False)
new_data = data[['RIX']]
new_data.to_csv(output_file, index=False)

# %% [markdown]
# ## Automated Readability Index
# 4.71 x (number of characters/number of words) + 0.5 x (number of words/number of sentences) – 21.43

# %%
input_file = 'new_output.csv'
output_file = 'scores.csv'
data = pd.read_csv(input_file)
new_data['ARI'] = round((4.71*(data['Total Chars'] / data['Total Words']))+ (0.5*(data['Total Words']/data['Total Sentence']))-21.43, 3)
new_data.to_csv(output_file, index=False)

# %% [markdown]
# ## Coleman-Liau Index
# 0.0588L - 0.296S - 15.8
# where L is the average number of letters per 100 words
# and S is the average number of sentences per 100 words

# %%
input_file = 'new_output.csv'
output_file = 'scores.csv'

data = pd.read_csv(input_file)
new_data['CLI'] = round((0.0588*100*(data['Total Chars'] / data['Total Words']))- (0.296*100*(data['Total Sentence']/data['Total Words']))-15.8, 3)
new_data.to_csv(output_file, index=False)

# %% [markdown]
# ## Dickes-Steiwer Handformel
# 235.95993 - (7.3021 x average number of characters per word) - (12.56438 x average number of words per sentence) - (50.03293 x type token ratio)

# %%
input_file = 'new_output.csv'
output_file = 'scores.csv'

data = pd.read_csv(input_file)
new_data['DSH'] = round(235.95993 - (7.3021*(data['Total Chars']/ data['Total Words'])) - (12.56438*(data['Total Words']/ data['Total Sentence'])) - (50.03293*(data['Unique Words']/data['Total Words'])),3)
new_data.to_csv(output_file, index=False)

# %% [markdown]
# ## Danielson Bryan
# 131.059 - (10.264 x (number of characters/ number of blanks)) + (0.0194 x (number of characters/ number of sentences))

# %%
input_file = 'new_output.csv'
output_file = 'scores.csv'

data = pd.read_csv(input_file)
new_data['DB'] = round((131.059 - (10.264*(data['Total Chars']/data['Blanks'])) + (0.0194*(data['Total Chars']/data['Total Sentence']))),3)
new_data.to_csv(output_file, index=False)

# %% [markdown]
# ## Fang's Easy Listening Formula
